# %%
import pandas as pd

# %%
df_train = pd.read_parquet('../data/train.parquet')

# %%
df_train.head(20)
# Out:
#                  event_time event_type product_id    brand    price  \
# 0   2019-11-01 00:00:14 UTC       cart    1005014  samsung   503.09
# 1   2019-11-01 00:03:39 UTC       cart    1005115    apple   949.47
# 2   2019-11-01 00:05:54 UTC       cart    1002542    apple   486.80
# 3   2019-11-01 00:07:22 UTC       cart    1002542    apple   486.80
# 4   2019-11-01 00:10:45 UTC       cart    4804056    apple   160.57
# 5   2019-11-01 00:13:40 UTC       cart    1004873  samsung   362.29
# 6   2019-11-01 00:14:09 UTC       cart    1004856  samsung   128.42
# 7   2019-11-01 00:14:23 UTC       cart    1004856  samsung   128.42
# 8   2019-11-01 00:15:23 UTC       cart    1005115    apple   949.47
# 9   2019-11-01 00:15:46 UTC       cart    1005116    apple  1013.86
# 10  2019-11-01 00:15:56 UTC       cart    1005116    apple  1013.86
# 11  2019-11-01 00:20:25 UTC       cart    1004870  samsung   275.25
# 12  2019-11-01 00:20:49 UTC       cart    1004870  samsung   275.25
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11495242 entries, 0 to 11495241
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   event_time    object
#  1   event_type    object
#  2   product_id    object
#  3   brand         object
#  4   price         object
#  5   user_id       object
#  6   user_session  object
#  7   target        int64
#  8   cat_0         object
#  9   cat_1         object
#  10  cat_2         object
#  11  cat_3         object
#  12  timestamp     datetime64[us, UTC]
#  13  ts_hour       int16
#  14  ts_minute     int16
#  15  ts_weekday    int16
#  16  ts_day        int16
#  17  ts_month      int16
#  18  ts_year       int16
# dtypes: datetime64[us, UTC](1), int16(6), int64(1), object(11)
# memory usage: 1.2+ GB

# %%
df_train.event_type.unique()
# Out:
# array(['cart', 'purchase'], dtype=object)

# %%
len(df_train.product_id.unique())
# Out:
# 164453

# %%
df_train.cat_1.unique()
# Out:
# array(['smartphone', 'audio', 'video', 'tablet', 'NA', 'notebook',
#        'clocks', 'skates', 'environment', 'sewing_machine', 'camera',
#        'kitchen', 'tools', 'accessories', 'telephone', 'peripherals',
#        'ebooks', 'toys', 'components', 'bedroom', 'swing', 'shoes',
#        'ironing_board', 'bicycle', 'carriage', 'bag', 'cartrige',
#        'desktop', 'bathroom', 'personal', 'dolls', 'iron', 'fmcg',
#        'living_room', 'lawn_mower', 'costume', 'tennis', 'trainer',
#        'underwear', 'shirt', 'dress', 'wallet', 'jumper', 'universal',
#        'tshirt', 'snowboard', 'jeans', 'ski', 'cultivator', 'scarf',
#        'glove', 'trousers', 'sock', 'belt', 'skirt', 'shorts', 'umbrella',
#        'furniture', 'pajamas', 'jacket', 'diving'], dtype=object)

# %%
# seleccionamos el usuario 533326659
df_train[df_train["user_id"] == "565865924"]
# Out:
#                     event_time event_type product_id    brand    price  \
# 1      2019-11-01 00:03:39 UTC       cart    1005115    apple   949.47
# 2661   2019-11-01 08:07:32 UTC       cart    1004237    apple  1091.29
# 31945  2019-11-02 16:40:22 UTC   purchase    1004249    apple   724.34
# 31985  2019-11-02 16:49:02 UTC   purchase    1004238    apple  1208.01
# 32019  2019-11-02 16:53:20 UTC   purchase    1004659  samsung   705.26
# 51402  2019-11-03 15:26:03 UTC   purchase    1004237    apple  1078.12
#
#          user_id                          user_session  target        cat_0  \
# 1      565865924  fd4bd6d4-bd14-4fdc-9aff-bd41a594f82e       0  electronics
# 2661   565865924  aa8209c8-4a12-4ce0-bd43-07b1fe51dd29       0  electronics
# 31945  565865924  46e81cd0-9f9d-4e75-ac03-dd21bfb4d0eb       1  electronics
# 31985  565865924  46e81cd0-9f9d-4e75-ac03-dd21bfb4d0eb       1  electronics
# 32019  565865924  46e81cd0-9f9d-4e75-ac03-dd21bfb4d0eb       1  electronics
# ...

# %%
len(df_train[df_train["target"] == 1 ])
# Out:
# 4190200

# %%
len(df_train[df_train["event_type"] == "purchase"])
# Out:
# 4190200

# %%
# cantidad de frecuencia de productos comprados
df_train[df_train["event_type"] == "purchase"].groupby("product_id").count().sort_values(by="event_type", ascending=False)
# Out:
#             event_time  event_type   brand   price  user_id  user_session  \
# product_id
# 1004767         143312      143312  143312  143312   143312        143312
# 1005115         113584      113584  113584  113584   113584        113584
# 1004856         106532      106532  106532  106532   106532        106532
# 1005100          91403       91403   91403   91403    91403         91403
# 4804056          84859       84859   84859   84859    84859         84859
# ...                ...         ...     ...     ...      ...           ...
# 27200346             1           1       1       1        1             1
# 2702652              1           1       1       1        1             1
# 100000002            1           1       1       1        1             1
# 100000018            1           1       1       1        1             1
# 100000023            1           1       1       1        1             1
#
# ...

# %%
df_train[df_train["product_id"]=="1005115"]
# Out:
#                        event_time event_type product_id  brand   price  \
# 1         2019-11-01 00:03:39 UTC       cart    1005115  apple  949.47
# 8         2019-11-01 00:15:23 UTC       cart    1005115  apple  949.47
# 43        2019-11-01 01:03:43 UTC       cart    1005115  apple  949.47
# 44        2019-11-01 01:04:16 UTC       cart    1005115  apple  949.47
# 45        2019-11-01 01:06:22 UTC       cart    1005115  apple  949.47
# ...                           ...        ...        ...    ...     ...
# 11495120  2020-01-31 23:17:40 UTC   purchase    1005115  apple  806.61
# 11495161  2020-01-31 23:34:31 UTC   purchase    1005115  apple  806.61
# 11495205  2020-01-31 23:46:36 UTC   purchase    1005115  apple  806.61
# 11495213  2020-01-31 23:49:49 UTC   purchase    1005115  apple  806.61
# 11495216  2020-01-31 23:50:26 UTC   purchase    1005115  apple  806.61
#
#             user_id                          user_session  target  \
# ...

# %%
df_train[df_train["product_id"]=="1004856"]
# Out:
#                        event_time event_type product_id    brand   price  \
# 6         2019-11-01 00:14:09 UTC       cart    1004856  samsung  128.42
# 7         2019-11-01 00:14:23 UTC       cart    1004856  samsung  128.42
# 16        2019-11-01 00:30:35 UTC       cart    1004856  samsung  128.42
# 53        2019-11-01 01:39:08 UTC       cart    1004856  samsung  128.42
# 54        2019-11-01 01:39:10 UTC       cart    1004856  samsung  128.42
# ...                           ...        ...        ...      ...     ...
# 11494830  2020-01-31 22:10:03 UTC   purchase    1004856  samsung  129.99
# 11495025  2020-01-31 22:51:02 UTC   purchase    1004856  samsung  129.99
# 11495043  2020-01-31 22:55:16 UTC   purchase    1004856  samsung  129.99
# 11495200  2020-01-31 23:45:17 UTC   purchase    1004856  samsung  129.99
# 11495202  2020-01-31 23:45:36 UTC   purchase    1004856  samsung  129.99
#
#             user_id                          user_session  target  \
# ...

# %%
df_amz = pd.read_csv("../data/amz/Amazon-Sale-Report.csv")

# %%
# configurar ver todas las columnas
pd.set_option('display.max_columns', None)

# %%
df_amz.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %%
df_amz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...
